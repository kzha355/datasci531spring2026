# %% [markdown]
# # <span style="color:red; font-size:30px"> Project: Graph Algorithms in Data & Decision Sciences </span>
#
# <font size = "4">
#
# This project is an open-ended exploration of graph algorithms in Data and Decision Sciences. You will identify an application whose solution can be handled by modeling it as a graph and implementing and applying an appropriate graph algorithm.
#
# You will do the following in a Jupyter notebook:
#
# - Formulate a real-word problem as a graph.
#
# - Implement at least one new (to us) graph algorithm from scratch. The following algorithms are already implemented in the `Graph` class of adjacency.py: Dijkstra's algorithm, Bellman-Ford algorithm, Prim's algorithm. So you should choose something else.
#
#     - Chapters 20-25 of "Introduction to Algorithms" by Cormen et al. covers a variety of graph algorithms, including pseudo-code.
#
#     - You can also choose an algorithm from another source (just cite what you use!)
#
# - Utilize this algorithm to solve your chosen problem.
#
# - Analyze/discuss correctness of the algorithm, runtime, and/or practical performance.
#
# - Present and interpret the results of your code and solution.

# %% [markdown]
# <font size = "4">
#
# **Expectations**
#
# - Cite all sources you used for your project.
#
# - LLM's can serve as great search engines, and feel free to use them to help find ideas for problems which can be solved using graph algorithms. But ultimately we want to minimize their use as much as possible:
#
#     - If you get an idea from an LLM, switch to a more reputable source to find more details about the problem and algorithm used to solve it.
#
#     - Implement the code yourself instead of the LLM doing it. You already have the classes from adjacency_graph.py to draw from, as well as other code covered in lecture.
#
#     - Make sure to cite your AI use, and describe how you used it.
#
# - In Markdown cells, introduce the problem, describe its graph representation, and what algorithm(s) can be used to solve it.
#
# - Include code that is clear and well-documented. Use Markdown cells to explain your implementation decisions and how the algorithm works.
#
# - Discuss or analyze the performance of your algorithm, either analytically or empirically. Consider one or more of the following: runtime complexity, space complexity, correctness of output.
#
# - Interpret your results and describe their connection to your chosen application.

# %% [markdown]
# <font size = "4">
#
# **Rubric (20 points)**
#
# - **Problem Formulation and Graph Modeling (4 points):** Clearly explain and motivate the problem, and describe/justify its graph representation
#
# - **Algorithm Implementation (5 points):** Implement a correct, "original" graph algorithm. Clearly explain its logic and structure.
#
# - **Performance Analysis (5 points):** Thoughtfully discuss the runtime/space complexity of your algorithm's performance and/or its correctness in solving the problem.
#
# - **Interpretation of Results (3 points):** Clearly summarize and interpret your results, and explain how they are applicable to your chosen problem.
#
# - **Clarity & Presentation (3 points):** Produce a well-written, organized notebook with clear figures and/or tables.
