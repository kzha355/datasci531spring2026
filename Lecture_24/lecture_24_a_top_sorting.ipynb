# %% [markdown]
# <font size = '4'>
#
# **Topological Sorting**
#
# - One application of a DFS search is **topological sorting**
#
# - A topological sort of a dag (directed acyclic graph) $G$ is a linear ordering of the vertices such that if $G$ contains an edge $(u, v)$, then $u$ appears before $v$ in that ordering.
#
# - Only defined for directed acyclic graphs, no linear ordering that preserves edge order is possible in a cyclic graph.
#
# - Here is an example of graph for a pancake recipe. Edges convey what steps need to be complete before others can begin:
#
# <div style="text-align: center;">
#   <img src="files/pancakes.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>Steps for making pancakes<br>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>

# %% [markdown]
# <font size = "4">
#
# The topological sorting algorithm proceeds as follows:
#
# 1. Call `G.dfs()` for the dag `G`. This is done primarily to compute the closing time for each vertex.
#
# 2. Store the vertices in a list in decreasing order of the closing time.
#
# 3. Return the ordered list as a result of the topological sort.
#
# Here is the result of DFS for the pancakes:
#
# <div style="text-align: center;">
#   <img src="files/pancakesDFS.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>Pancake steps after DFS<br>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# Here is the result of the topological sort:
#
# <div style="text-align: center;">
#   <img src="files/pancakesTS.png" alt="Centered image" width = "750">
#   <br>
#   <br>
#   <figcaption>Topologically sorted Pancake recipe<br>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>

# %%
from adjacency_graph import Graph

class DFSGraph(Graph):
    def __init__(self):
        super().__init__()
        self.time = 0

    def dfs(self):
        for vertex in self:
            vertex.color = "white"
            vertex.previous = -1
        for vertex in self:
            if vertex.color == "white":
                self.dfs_visit(vertex)

    def dfs_visit(self, start_vertex):
        start_vertex.color = "gray"
        self.time = self.time + 1
        start_vertex.discovery_time = self.time
        for next_vertex in start_vertex.get_neighbors():
            if next_vertex.color == "white":
                next_vertex.previous = start_vertex
                self.dfs_visit(next_vertex)
        start_vertex.color = "black"
        self.time = self.time + 1
        start_vertex.closing_time = self.time

# %%
G = DFSGraph()
G.set_vertex("3/4 cup milk")
G.set_vertex("heat griddle")
G.add_edge("1 egg", "1 cup mix")
G.add_edge("3/4 cup milk", "1 cup mix")
G.add_edge("1 cup mix", "pour 1/4 cup")
G.add_edge("heat griddle", "pour 1/4 cup")
G.add_edge("1 Tbl Oil", "1 cup mix")
G.add_edge("pour 1/4 cup", "turn when bubbly")
G.add_edge("1 cup mix", "heat syrup")
G.add_edge("heat syrup", "eat")
G.add_edge("turn when bubbly", "eat")

G.dfs()

# %%
list(G.get_vertices())

# %%
G.get_vertex('1 egg').closing_time > G.get_vertex('eat').closing_time

# %%
def precedes(key1, key2, G):
    return G.get_vertex(key1).closing_time > G.get_vertex(key2).closing_time


G_vertices = list(G.get_vertices())

# just do bubble_sort (not quick_sort!) because it's easy
n = len(G_vertices)
for p in range(n-1):
    for i in range(n-p-1):
        if precedes(G_vertices[i+1], G_vertices[i], G):
            G_vertices[i+1], G_vertices[i] = G_vertices[i], G_vertices[i+1]

print(G_vertices)
