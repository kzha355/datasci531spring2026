# %% [markdown]
# <font size = "4">
#
# **Strongly connected components**
#
# - Let $G = (V, E)$ be a directed graph. A **strongly connected component (SCC)** is the largest subset of vertices $C \subset V$ such that for every pair of vertices $v, w \in C$, there exists a path from $v$ to $w$ and a path from $w$ to $v$.
#
# - Here is a small graph with 3 SCC's identified by the shaded areas:
#
# <div style="text-align: center;">
#   <img src="files/scc1.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# - We can represent a simplified view of the graph by "collapsing" the SCC's into a single vertex:
#
# <div style="text-align: center;">
#   <img src="files/scc2.png" alt="Centered image" width = "325">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>

# %% [markdown]
# <font size = "4">
#
# **Transpose of a graph**
#
# - Let $G = (V, E)$ be a directed graph. The **transpose** of $G$ is the graph $G^T = (V, E^T)$, where $E^T$ is obtained by reversing the direction of the edges in $E$.
#
# - A simple graph:
#
# <div style="text-align: center;">
#   <img src="files/transpose1.png" alt="Centered image" width = "175">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# - And its transpose:
#
# <div style="text-align: center;">
#   <img src="files/transpose2.png" alt="Centered image" width = "175">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>

# %% [markdown]
# <font size = "4">
#
# **SCC Algorithm**
#
# To compute the strongly connected components of a directed graph $G$, we can do the following:
#
# 1. Call `dfs` for the graph $G$ to compute the closing times for each vertex.
#
# 2. Compute $G^T$.
#
# 3. Call `dfs` for the graph $G^T$, but in the main loop of `dfs`, explore each vertex in decreasing order of closing time.
#
# 4. After step 3, each tree in the forest is a strongly connected component.

# %% [markdown]
# <font size = "4">
#
# We'll simply describe the algorithm visually with the example from above, reproduced here:
#
# <div style="text-align: center;">
#   <img src="files/scc1.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# - Use DFS to get closing times for the vertices:
#
# <div style="text-align: center;">
#   <img src="files/scc1a.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# - Use DFS on the transpose, visiting each vertex in descending order of closing time:
#
# <div style="text-align: center;">
#   <img src="files/scc1b.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
#
# <br>
#
# <font size = "4">
#
# - Each tree in the resulting forest is a strongly connected component:
#
# <div style="text-align: center;">
#   <img src="files/sccforest.png" alt="Centered image" width = "350">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "1"> Miller, Randum, Yasinovskyy (Problem Solving with Algorithms and Data Structures using Python)</figcaption>
# </div>
